# %%
pip install pypdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypdf import PdfReader

# %%
pdf_file = PdfReader(r'/Users/akhileshjanib/Documents/Sanika_Documents/Sanika_Appointment.pdf')

# %%
pdf_file

# %%
pdf_text = ''
for page in pdf_file.pages:
  pdf_text += page.extract_text()

# %%
#pip install cryptography >3.1
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
print(pdf_text)
# Out:
#
#
# Konverge Technologies Pvt Ltd.
#
#  D-502, 5th Floor, Lotus Corporate Park, 185 A, Gramfilth Steel Compound, Gaothan Road, Goregaon East, Mumbai, 400063. India. Tel : +91 2266810422,
# CIN: U72200HR2013PTC048898
#
#
# 28th October, 2022
#
# To,
# Ms. Sanika Katneshwarkar
# E3- 908, SMR, Vinay Estella,
# Vidyaranyapura,
# Bangalore- 560097
#
# Dear Ms. Sanika,
# We welcome you to Konverge Technologies, and are confident that you will build a long and mutually rewarding
# career with us. We believe that it is individuals like you who can along with all of us build a world-class company.
# Konverge Technologies provides long-term career opportunities for every individual. We sincerely hope that, you
# will grow with us and develop a memorable institution.
# Enclosed please find your employment letter and other relevant details. Meanwhile, if you would like to know
# more about the company or for any other clarifications, please contact Shrutika Salvi.
#
# Thanking you,
# ...
